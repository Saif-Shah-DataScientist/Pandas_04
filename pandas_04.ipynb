# %%
import pandas as pd

# %%
car=pd.read_csv("car.csv")

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# # Data cleaning
#     -missing values:
#         Drop:
#         -Drop the record having missing data
#         -Drop the column having missing data
#         Fill:
#          -fill the missing values
#              -hard-coded value
#              -Calculated values
#              -Following or Precending
#
#     -Duplicate values, Records
#     -outlier

# %% [markdown]
# # Missing values: isna() isnull()

# %%
car.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %% [markdown]
# ###  Drop all the missing record
#     -by using drop function

# %%
car["kms_driven"].isna().sum()
# Out:
# 52

# %%
car.dropna() # drop row having null type
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
car.dropna(axis=1) # drop column having missing values (vertical)
# Out:
#                                        name    company  year          Price
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
# [892 rows x 4 columns]

# %%
car.dropna(axis=0) #drop row having missing values (horizontal)
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
car.dropna(how='all',axis=0) # drop only those record where all   values are missing
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
# drop only those record where all   values are missing
car.dropna(how='any' , axis=0)
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
# drop only those column where all values are missing
car.dropna(how='all',axis=1)
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
#drop any column where all values are missing
car.dropna(how='any',axis=1)
# Out:
#                                        name    company  year          Price
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
# [892 rows x 4 columns]

# %% [markdown]
# ### thresh paramerte

# %%
#retain all the records where at least five values are valid
car.dropna(axis=0 ,thresh=5)
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
# thresh by 70%
int(car.shape[1]*.70)
# Out:
# 4

# %%
car.dropna(axis=0,thresh=int(car.shape[1]*.70))
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %% [markdown]
# #### for column

# %%
car.dropna(axis=1,thresh=int(car.shape[0]*.70))
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %% [markdown]
# ### subset:

# %%
#drop all those record where any  values are missing in subset
car.dropna(axis=0,subset=['year','Price','kms_driven'])
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 886                    Toyota Corolla Altis     Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#        kms_driven fuel_type
# ...

# %%
#drop all those records where all values are missing in the subset
car.dropna(axis=0,subset=['year','Price','kms_driven'] , how='all')
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %% [markdown]
# # filling data

# %%
# fill all the missing value with hardcoded value giving in parametr like 0 we did
car.fillna(0)
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %% [markdown]
# ## Filling missing data by using Mean,Median,Mode,Min and Max

# %% [markdown]
# #### Central Tendency:
#     -if there is outlier in data we will use median
#     -if there is no outlier in data we will use mean
#     -for categorical data we will mode
# ### Bfill() , ffill()

# %%
import numpy as np

# %%
import numpy as np
ages=np.array([13,53,64,24,65,2,34,87,23,76,54,22])
ages
# Out:
# array([13, 53, 64, 24, 65,  2, 34, 87, 23, 76, 54, 22])

# %%
ages=[2,13,22,23,24,34,53,54,64,65,76,87]
ages
# Out:
# [2, 13, 22, 23, 24, 34, 53, 54, 64, 65, 76, 87]

# %%
int(ages.mean())
# Out:
# 43

# %%
import seaborn as sns

# %%
sns.boxplot(ages)
# Out:
# <Axes: >

# %% [markdown]
# # mode

# %%
car.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
car.fuel_type.value_counts()
# Out:
# fuel_type
# Petrol    440
# Diesel    395
# LPG         2
# Name: count, dtype: int64

# %%
car.fuel_type.mode()
# Out:
# 0    Petrol
# Name: fuel_type, dtype: object

# %%
car.isna().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
car.kms_driven
# Out:
# 0      45,000 kms
# 1          40 kms
# 2      22,000 kms
# 3      28,000 kms
# 4      36,000 kms
#           ...
# 887           NaN
# 888    27,000 kms
# 889    40,000 kms
# 890        Petrol
# 891        Petrol
# Name: kms_driven, Length: 892, dtype: object

# %%
car[car.kms_driven=="Petrol"]
# Out:
#                           name    company  year     Price kms_driven fuel_type
# 890   Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000     Petrol       NaN
# 891  Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000     Petrol       NaN

# %%
car.kms_driven.replace("Petrol",0 , inplace=True)

# %%
car.kms_driven
# Out:
# 0      45,000 kms
# 1          40 kms
# 2      22,000 kms
# 3      28,000 kms
# 4      36,000 kms
#           ...
# 887           NaN
# 888    27,000 kms
# 889    40,000 kms
# 890             0
# 891             0
# Name: kms_driven, Length: 892, dtype: object

# %%
car.kms_driven=car.kms_driven.str.replace("kms","").str.replace(",","").astype(float)

# %%
car.kms_driven
# Out:
# 0      45000.0
# 1         40.0
# 2      22000.0
# 3      28000.0
# 4      36000.0
#         ...
# 887        NaN
# 888    27000.0
# 889    40000.0
# 890        NaN
# 891        NaN
# Name: kms_driven, Length: 892, dtype: float64

# %%
sns.boxplot(car.kms_driven)
# Out:
# <Axes: ylabel='kms_driven'>

# %% [markdown]
# # for missing data we use median because boxplot has outlier that's why we use median for filling

# %%
car.kms_driven=car.kms_driven.fillna(car.kms_driven.median())

# %%
car.kms_driven.replace(0,car.kms_driven.median(),inplace=True)

# %%
car.kms_driven
# Out:
# 0      45000.0
# 1         40.0
# 2      22000.0
# 3      28000.0
# 4      36000.0
#         ...
# 887    41000.0
# 888    27000.0
# 889    40000.0
# 890    41000.0
# 891    41000.0
# Name: kms_driven, Length: 892, dtype: float64

# %% [markdown]
# ## mode for categorial:
#     - two ways :- that can't fill because maybe NAN will be mode
#     car.fuel_type.mode()=>it bring series thats why we always gives index
#     0    Petrol
#     Name: fuel_type, dtype: object
#     -final script=>car.fuel_type.fillna(car.fuel_type.mode()[0])

# %%
car.fuel_type.mode()[0]
# Out:
# 'Petrol'

# %%
car.fuel_type.fillna(car.fuel_type.mode()[0])
# Out:
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
#         ...
# 887    Petrol
# 888    Diesel
# 889    Diesel
# 890    Petrol
# 891    Petrol
# Name: fuel_type, Length: 892, dtype: object

# %%
car[car.Price=="Ask For Price"]
# Out:
#                                           name     company  year  \
# 2                   Maruti Suzuki Alto 800 Vxi      Maruti  2018
# 5             Ford EcoSport Titanium 1.5L TDCi        Ford  2015
# 69             I want to sell my car Tata Zest           I  2017
# 85             I want to sell my car Tata Zest           I  2017
# 138                 Maruti Suzuki Alto 800 Lxi      Maruti  2018
# 185     Commercial , DZire LDI, 2016, for sale  Commercial   ...
# 286     Commercial , DZire LDI, 2016, for sale  Commercial   ...
# 295                    Maruti Suzuki Swift LDi      Maruti  2010
# 304                         Tata Indica eV2 LS        Tata  2017
# 360                             selling car Ta     selling  Zest
# 368                               Tata Zest 90        Tata  /-Rs
# 388                 Maruti Suzuki Alto 800 Lxi      Maruti  2018
# 449     Maruti Suzuki Zen Estilo LXI Green CNG      Maruti  2011
# ...

# %%
car.Price.replace("Ask For Price",0,inplace=True)
